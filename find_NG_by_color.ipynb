# %%
import numpy as np 
import cv2
from glob import glob
import os

# %%
#進入dataset資料夾
# %cd  ./Downloads/whole_image_swin
# Out:
# [WinError 3] 系統找不到指定的路徑。: './Downloads/whole_image_swin'
# C:\Users\MA201-202101\Downloads\whole_image_swin

# %%
#路徑和檔名分割處須視情況改
img =glob('C:/Users/MA201-202101/Downloads/whole_image_resnet101/*')
path = 'C:/Users/MA201-202101/Downloads/whole_image_resnet101/'
destination = 'C:/Users/MA201-202101/Downloads/NG_for_resnet/'
for a,i in enumerate(img):
    target = img[a]
    target = target.split('\\')[1]
    target2 = target.split('.')[0]
    im = cv2.imread(i)
# #     進入此張圖的1920X1280
    for j in range(len(im)):
        for k in range(len(im[0])):
            if (im[j][k][0]==im[j][k][1]==im[j][k][2]):
                pass
            else:
                os.replace(path+target,destination+target)
                break
        else:
            continue
        break
    print('complete', a)
    continue
# Out:
# complete 0
# complete 1
# complete 2
# complete 3
# complete 4
# complete 5
# complete 6
# complete 7
# complete 8
# complete 9
# complete 10
# complete 11
# complete 12
# complete 13
# complete 14
# complete 15
# complete 16
# complete 17
# complete 18
# complete 19
# complete 20
# complete 21
# complete 22
# complete 23
# complete 24
# complete 25
# complete 26
# complete 27
# complete 28
# complete 29
# complete 30
# complete 31
# complete 32
# complete 33
# complete 34
# complete 35
# complete 36
# complete 37
# complete 38
# complete 39
# complete 40
# complete 41
# complete 42
# complete 43
# complete 44
# complete 45
# complete 46
# complete 47
# complete 48
# complete 49
# complete 50
# complete 51
# complete 52
# complete 53
# complete 54
# complete 55
# complete 56
# complete 57
# complete 58
# complete 59
# complete 60
# complete 61
# complete 62
# complete 63
# complete 64
# complete 65
# complete 66
# complete 67
# complete 68
# complete 69
# complete 70
# complete 71
# ...
